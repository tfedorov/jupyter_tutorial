# %%
import random
import numpy as np
def generateData(rank, max_number = 100):
    raw = []
    if(rank < 0):
        raise
    for x in range(rank):
        x1 = random.randint(0,max_number)
        x2 = random.randint(0,max_number)
        x3 = random.randint(0,max_number)
        isDivided = (x1 + x2 + x3) < 150
        x4 = 0 if (isDivided) else 1
        raw.append([x1, x2, x3, x4])
    return np.array(raw)

# %%
all_data = generateData(75)
#print(all_data)

# %%
train_data = all_data[:,0:3]
labels = all_data[:,3:4]

# %%
# Create first network with Keras
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(12, input_dim=3, init='uniform', activation='relu'))
model.add(Dense(8, init='uniform', activation='relu'))
model.add(Dense(1, init='uniform', activation='sigmoid'))
# Out:
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(12, input_dim=3, activation="relu", kernel_initializer="uniform")`
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(8, kernel_initializer="uniform", activation="relu")`
#   app.launch_new_instance()
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:4: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_initializer="uniform", activation="sigmoid")`

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
score = model.evaluate(train_data, labels)
# Out:
# 32/75 [===========>..................] - ETA: 0s

# %%
model.fit(train_data, labels, nb_epoch=150, batch_size=10,  verbose=2)
# Out:
# /opt/conda/lib/python3.5/site-packages/keras/models.py:848: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Epoch 1/150
# 0s - loss: 0.6876 - acc: 0.5600
# Epoch 2/150
# 0s - loss: 0.6798 - acc: 0.5600
# Epoch 3/150
# 0s - loss: 0.6718 - acc: 0.5600
# Epoch 4/150
# 0s - loss: 0.6575 - acc: 0.5600
# Epoch 5/150
# 0s - loss: 0.6435 - acc: 0.5600
# Epoch 6/150
# 0s - loss: 0.6318 - acc: 0.5600
# Epoch 7/150
# 0s - loss: 0.6277 - acc: 0.5600
# Epoch 8/150
# 0s - loss: 0.6224 - acc: 0.5600
# Epoch 9/150
# 0s - loss: 0.6216 - acc: 0.5600
# Epoch 10/150
# 0s - loss: 0.6197 - acc: 0.5600
# Epoch 11/150
# 0s - loss: 0.6183 - acc: 0.5600
# Epoch 12/150
# 0s - loss: 0.6172 - acc: 0.5600
# Epoch 13/150
# 0s - loss: 0.6158 - acc: 0.5600
# Epoch 14/150
# 0s - loss: 0.6159 - acc: 0.5600
# Epoch 15/150
# 0s - loss: 0.6130 - acc: 0.5600
# Epoch 16/150
# 0s - loss: 0.6151 - acc: 0.5600
# Epoch 17/150
# ...

# %%
predictions = model.predict(np.array([47,  24,  12]).reshape(1,3))
print(predictions)
# Out:
# [[ 0.03707761]]

# %%
all_data
# Out:
# array([[ 71,  67,  25,   1],
#        [ 98,  47,  43,   1],
#        [ 47,  24,  12,   0],
#        [ 64,  91,  33,   1],
#        [ 63,  31, 100,   1],
#        [  7,  38,  91,   0],
#        [ 45,  63,  65,   1],
#        [ 87,  81,  27,   1],
#        [  4,  81,  11,   0],
#        [ 79,  67,  40,   1],
#        [ 92,  70,  66,   1],
#        [ 36,  74,  81,   1],
#        [ 22,  59,  54,   0],
#        [ 78,  94,  99,   1],
#        [ 22,  37,  33,   0],
#        [ 57,  32,  42,   0],
#        [ 49, 100,  66,   1],
#        [ 23,   9,  11,   0],
#        [ 24,  63,  50,   0],
#        [ 63,  21,  22,   0],
#        [ 45,  25,  22,   0],
#        [ 14,  91,  93,   1],
#        [ 57,  23,  76,   1],
#        [ 76,  95,  43,   1],
#        [ 59,  23,  41,   0],
#        [ 91,  48,  81,   1],
#        [ 69,  73,  93,   1],
#        [ 41,  46,  45,   0],
#        [ 50,   2,  12,   0],
#        [ 30,  20,  24,   0],
#        [ 52,  25,  86,   1],
#        [ 80,   4,  97,   1],
# ...
